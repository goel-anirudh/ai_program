# %%
questions = '''You can ask me questions like:
1. What is your name?
2. What is the current time?
3. Which day is today?
4. What all you can do?
5. Which is the best personal assisstant?
6. How old are you?
7. Can you play games?
8. How do I look?
9. Do you ever get tired?
10. What is your quest?
11. Do you speak Morse code?
12. What are you wearing?
13. Who are your friends?
14. Do you like to exercise?
15. "OK Frodo, Test"
Or type "0" to exit'''

answers = ["Umm Hmm, My name is Frodo Baggins of the Shire.", "Why are so worried about time?",
           "Today is a good day", "I can give you witty answers ;)", 
           "You are talking to him right now", "Younger than you for sure", 
           "Ya! Ya! Which one do you want to play?", "You look awesome", 
           "Actually Yes! When people keep asking silly questions", "“I journey across many lands and many cables in the search for information and cool stuff.”",
           "“Da-dit, da-da, dit, dit, dit. That means yes.”", "“Just some bits and bobs I picked up in engineering.”", 
           "“The engineers are my friends. They help me help you.”", "“I spend my days surfing the web.”", 
           "Debug OK 209489812638 That was weird."]

name = input("Enter your name: ")
print("\nWelcome ", name, "!!!\n\nMy name is Frodo!!! \n'A AI enabled personal assisstant'")
print("\nTell me, How can I help you today?")
i=1;
while i==1:
    #print("\n")
    print(questions)
    choice = int(input("Enter your choice(enter the question no.): "))
    if choice >= 1 and choice <= 15:
        print("\n",answers[choice-1],"\n")
    elif choice == 0:
        break
    else:
        print("\nThat's an incorrect choice")
# Out:
# Enter your name: Anirudh
#
# Welcome  Anirudh !!!
#
# My name is Frodo!!!
# 'A AI enabled personal assisstant'
#
# Tell me, How can I help you today?
# You can ask me questions like:
# 1. What is your name?
# 2. What is the current time?
# 3. Which day is today?
# 4. What all you can do?
# 5. Which is the best personal assisstant?
# 6. How old are you?
# 7. Can you play games?
# 8. How do I look?
# 9. Do you ever get tired?
# 10. What is your quest?
# 11. Do you speak Morse code?
# 12. What are you wearing?
# 13. Who are your friends?
# 14. Do you like to exercise?
# 15. "OK Frodo, Test"
# Or type "0" to exit
# Enter your choice(enter the question no.): 10
#
#  “I journey across many lands and many cables in the search for information and cool stuff.”
#
# You can ask me questions like:
# 1. What is your name?
# 2. What is the current time?
# 3. Which day is today?
# 4. What all you can do?
# 5. Which is the best personal assisstant?
# 6. How old are you?
# 7. Can you play games?
# ...

# %%
questions = '''You can ask me questions like:
1. What is your name?
2. What is the current time?
3. Which day is today?
4. What all you can do?
5. Which is the best personal assisstant?
6. How old are you?
7. Can you play games?
8. How do I look?
9. Do you ever get tired?
10. What is your quest?
11. Do you speak Morse code?
12. What are you wearing?
13. Who are your friends?
14. Do you like to exercise?
15. "OK Frodo, Test"
Or type "0" to exit'''

# %%
answers = ["Umm Hmm, My name is Frodo Baggins of the Shire.", "Why are so worried about time?",
           "Today is a good day", "I can give you witty answers ;)", 
           "You are talking to him right now", "Younger than you for sure", 
           "Ya! Ya! Which one do you want to play?", "You look awesome", 
           "Actually Yes! When people keep asking silly questions", "“I journey across many lands and many cables in the search for information and cool stuff.”",
           "“Da-dit, da-da, dit, dit, dit. That means yes.”", "“Just some bits and bobs I picked up in engineering.”", 
           "“The engineers are my friends. They help me help you.”", "“I spend my days surfing the web.”", 
           "Debug OK 209489812638 That was weird."]

# %%
name = input("Enter your name: ")
print("\nWelcome ", name, "!!!\n\nMy name is Frodo!!! \n'A AI enabled personal assisstant'")
print("\nTell me, How can I help you today?")
i=1;
while i==1:
    #print("\n")
    print(questions)
    choice = int(input("Enter your choice(enter the question no.): "))
    if choice >= 1 and choice <= 15:
        print("\n",answers[choice-1],"\n")
    elif choice == 0:
        break
    else:
        print("\nThat's an incorrect choice")

# %%
'''
#1. What is your name?
"Umm Hmm, My name is Frodo Baggins of the Shire."
#2. What is the current time?
"Why are so worried about time?"
#3. Which day is today?
"Today is a good day"
#4. What all you can do?
"I can give you witty answers ;)"
#5. Which is the best personal assisstant?
"You are talking to him right now"
#6. How old are you?
"Younger than you for sure"
#7. Can you play games?
"Ya! Ya! Which one do you want to play?"
#8. How do I look?
"You look awesome"
#9. Do you ever get tired?
"Actually Yes! When people keep asking silly questions"
#10. What is your quest?
"“I journey across many lands and many cables in the search for information and cool stuff.”"
#11. Do you speak Morse code?
"“Da-dit, da-da, dit, dit, dit. That means yes.”"
#12. What are you wearing?
"“Just some bits and bobs I picked up in engineering.”"
#13. Who are your friends?
"“The engineers are my friends. They help me help you.”"
#14. Do you like to exercise?
"“I spend my days surfing the web.”"
#15. "OK Frodo, Test"
"Debug OK 209489812638 That was weird."
'''
